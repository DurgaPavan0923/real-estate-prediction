# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Real estate.csv')

# %%
df.rename(columns={
    'X1 transaction date': 'transaction_date',
    'X2 house age': 'house_age',
    'X3 distance to the nearest MRT station': 'distance',
    'X4 number of convenience stores': 'convenience_stores',
    'Y house price of unit area': 'price'
}, inplace=True)

# %%
df.rename(columns={
    'X5 latitude': 'latitude',
    'X6 longitude': 'longitude'
}, inplace=True)

df.head()
# Out:
#    No  transaction_date  house_age   distance  convenience_stores  latitude  \
# 0   1          2012.917       32.0   84.87882                  10  24.98298
# 1   2          2012.917       19.5  306.59470                   9  24.98034
# 2   3          2013.583       13.3  561.98450                   5  24.98746
# 3   4          2013.500       13.3  561.98450                   5  24.98746
# 4   5          2012.833        5.0  390.56840                   5  24.97937
#
#    longitude  price
# 0  121.54024   37.9
# 1  121.53951   42.2
# 2  121.54391   47.3
# 3  121.54391   54.8
# 4  121.54245   43.1

# %%
# Correlation matrix
correlation_matrix = df.corr(numeric_only=True)

# Correlation of each column with 'price'
print(correlation_matrix['price'].sort_values(ascending=False))
# Out:
# price               1.000000
# latitude            0.546307
# longitude           0.523287
# transaction_date    0.087491
# No                 -0.028587
# Name: price, dtype: float64

# %%
df.drop(columns=['distance', 'house_age', 'convenience_stores'], inplace=True)

# %%
df.head()
# Out:
#    No  transaction_date  latitude  longitude  price
# 0   1          2012.917  24.98298  121.54024   37.9
# 1   2          2012.917  24.98034  121.53951   42.2
# 2   3          2013.583  24.98746  121.54391   47.3
# 3   4          2013.500  24.98746  121.54391   54.8
# 4   5          2012.833  24.97937  121.54245   43.1

# %%
#1. Histogram of Price (target variable)
import matplotlib.pyplot as plt

df['price'].hist(bins=20, color='skyblue', edgecolor='black')
plt.title('Histogram of Price')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
import seaborn as sns

sns.scatterplot(x='latitude', y='price', data=df)
plt.title('Latitude vs Price')
plt.grid(True)
plt.show()

# %%
sns.scatterplot(x='longitude', y='price', data=df)
plt.title('Longitude vs Price')
plt.grid(True)
plt.show()

# %%
sns.scatterplot(x='transaction_date', y='price', data=df)
plt.title('Transaction Date vs Price')
plt.grid(True)
plt.show()
