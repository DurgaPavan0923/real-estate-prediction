# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("../data/folder/cleaned_data_with_transaction_year.csv")

print(f"Dataset shape: {df.shape}")
df.head()
# Out:
# Dataset shape: (414, 8)
#    transaction_date  house_age  distance_to_mrt  num_convenience_stores  \
# 0          2012.917   0.730594         0.009513                     1.0
# 1          2012.917   0.445205         0.043809                     0.9
# 2          2013.583   0.303653         0.083315                     0.5
# 3          2013.500   0.303653         0.083315                     0.5
# 4          2012.833   0.114155         0.056799                     0.5
#
#    latitude  longitude  price_per_unit_area  transaction_year
# 0  0.616941   0.719323                 37.9              2012
# 1  0.584949   0.711451                 42.2              2012
# 2  0.671231   0.758896                 47.3              2013
# 3  0.671231   0.758896                 54.8              2013
# 4  0.573194   0.743153                 43.1              2012

# %%
sns.histplot(df['price_per_unit_area'], kde=True)
plt.title("Price Distribution")
plt.xlabel("Price per Unit Area")
plt.ylabel("Frequency")
plt.show()

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", center=0, square=True)
plt.title("Feature Correlation Heatmap")
plt.tight_layout()
plt.show()
